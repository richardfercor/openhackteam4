# %%
import os
import numpy as np
from PIL import Image, ImageOps
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier


#from sklearn.datasets import make_classification
f = []
path ="C:/Users/rfernandez3/Documents/OpenHackImages/gear_imagesmod/"
path_destination=path.replace('gear_images','gear_imagesmod')     
listOfDirs = os.listdir(path)
images=np.empty
labels=np.empty
tags=np.empty
images_train=np.empty
images_test=np.empty
i=0
for l in listOfDirs:
    print(l)
    listOfFiles = os.listdir(str(path)+str(l))
    tags=np.append(tags,l)
    for lf in listOfFiles:
        original_image=Image.open(path+l+'/'+lf)
        imgnp = np.asarray(original_image)  
        
        if images is None:
            images=imgnp.reshape(imgnp.shape[0],-1).T
        else:
            images=np.append(images,,,)
        if labels is None:
            labels=np.array(l)
        else:
            labels=np.append(labels,np.array(l))
    i=i+1
    if (i==3):
        break
print(type(images))
#    train_indexes=len(listOfFiles)*0.8
#    test_indexes=-(len(listOfFiles)*0.2)
    #images_train_tmp=np.array(images[train_indexes,:])
X_train, X_test, y_train, y_test=train_test_split(images,labels,test_size=0.2)



clf = RandomForestClassifier(max_depth=2, random_state=0)
#train_set_y=images_train[:,1]
print(X_train[1])
print(y_train[0])
#test_set_y=images_test[1]
#print(test_set_y)
#train_set_x_flatten=images_train.reshape(X_train.shape[0],-1).T
#test_set_x_flatten=images_test.reshape(X_test.shape[0],-1).T
clf.fit(X_train, y_train)
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=2, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
            oob_score=False, random_state=0, verbose=0, warm_start=False)
print(clf.feature_importances_)

print(clf.predict([[0, 0, 0, 0]]))
# Out:
# axes
# boots
# carabiners
# <class 'numpy.ndarray'>
# <built-in method flatten of numpy.ndarray object at 0x00000225B9A338A0>
# carabiners
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-be685b2902eb> in <module>()
#      52 #train_set_x_flatten=images_train.reshape(X_train.shape[0],-1).T
#      53 #test_set_x_flatten=images_test.reshape(X_test.shape[0],-1).T
# ---> 54 clf.fit(X_train, y_train)
#      55 RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#      56             max_depth=2, max_features='auto', max_leaf_nodes=None,
#
# c:\users\rfernandez3\appdata\local\continuum\anaconda3\envs\py352\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
# ...

# %%
import os
import numpy as np
from PIL import Image, ImageOps
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier


#from sklearn.datasets import make_classification
f = []
path ="C:/Users/rfernandez3/Documents/OpenHackImages/gear_imagesmod/"
path_destination=path.replace('gear_images','gear_imagesmod')     
listOfDirs = os.listdir(path)
images=None
labels=None
tags=np.empty
images_train=np.empty
images_test=np.empty
i=0
files=0
for l in listOfDirs:
    print(l)
    listOfFiles = os.listdir(str(path)+str(l))
    tags=np.append(tags,l)
    for lf in listOfFiles:
        original_image=Image.open(path+l+'/'+lf)
        imgnp = np.asarray(original_image)
        if images is None:
            images=imgnp
        else:
            images=np.concatenate((images,imgnp),axis=0)
        files=files+1
        #print(imgnp.shape)
        if labels is None:
            labels=np.array(l)
        else:
            labels=np.append(labels,np.array(l))
    i=i+1
    if (i==10):
        break
images=images.reshape((files,128,128,3))

print(images.shape)
print(labels.shape)


#END 


#    train_indexes=len(listOfFiles)*0.8
#    test_indexes=-(len(listOfFiles)*0.2)
    #images_train_tmp=np.array(images[train_indexes,:])
X_train, X_test, y_train, y_test=train_test_split(images,labels,train_size=0.8,test_size=0.2)
#print(X_train.shape)
#print(X_test.shape)
#print(y_train.shape)
#print(y_test.shape)
# Out:
# axes
# boots
# carabiners
# crampons
# gloves
# hardshell_jackets
# harnesses
# helmets
# insulated_jackets
# pulleys
# (1811, 128, 128, 3)
# (1811,)
# (1448, 49152)
# [0. 0. 0. ... 0. 0. 0.]
# score:0.6942148760330579

# %%
clf = RandomForestClassifier(max_depth=16, random_state=0)
#train_set_y=images_train[:,1]


#test_set_y=images_test[1]
#print(test_set_y)
train_set_x_flatten=X_train.reshape(X_train.shape[0],-1)
print(train_set_x_flatten.shape)
test_set_x_flatten=X_test.reshape(X_test.shape[0],-1)
clf.fit(train_set_x_flatten, y_train)
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=10, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=3, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
            oob_score=False, random_state=0, verbose=0, warm_start=False)
print(clf.feature_importances_)


print("score:" +str(clf.score(test_set_x_flatten,y_test)))
# Out:
# (1448, 49152)
# [0. 0. 0. ... 0. 0. 0.]
# score:0.8236914600550964
